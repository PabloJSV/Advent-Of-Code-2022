# %%
block1 = ['N', 'T', 'B', 'S', 'Q', 'H', 'G', 'R']
block2 = ['J', 'Z', 'P', 'D', 'F', 'S', 'H']
block3 = ['A', 'O', 'E', 'I', 'U', 'L', 'N', 'R', 'S', 'T']
block4 = ['V', 'H', 'Z']
block5 = ['H', 'G', 'F', 'J', 'Z', 'M']
block6 = ['R', 'S', 'M', 'L', 'D', 'C', 'Z', 'T']
block7 = ['J', 'Z', 'H', 'V', 'W', 'T', 'M']
block8 = ['Z', 'L', 'P', 'F', 'T']
block9 = ['S', 'W', 'V', 'Q']
block10 = ['C', 'N', 'D', 'T', 'M', 'L', 'H', 'W']

how_many = 3
block_from = 1
block_to = 2
print('block_from is ' + str(block_from))
if block_from == 1:
        block_from = block1  
        print(block_from)
        movinglist = (block1[:(how_many)])
        print(movinglist)
        movinglist = movinglist[::-1]
        print(movinglist)
        block1 = block1[how_many:]
        print(block1)
        if block_to == 1:
            block1 = movinglist + block1
            print(block1)
        if block_to == 2:
            block2 = movinglist + block2
            print(block2)
        if block_to == 3:
            block3 = movinglist + block3
            print(block3)
        if block_to == 4:
            block4 = movinglist + block4
            print(block4)
        if block_to == 5:
            block5 = movinglist + block5
            print(block5)
        if block_to == 6:
            block6 = movinglist + block6
            print(block6)
        if block_to == 7:
            block7 = movinglist + block7
            print(block7)
        if block_to == 8:
            block8 = movinglist + block8
            print(block8)
        if block_to == 9:
            block9 = movinglist + block9
            print(block9)
if block_from == 2:
        block_from = block2  
        print(block_from)
        movinglist = (block2[:(how_many)])
        print(movinglist)
        block2 = block2[how_many:]
        print(block1)
        if block_to == 1:
            block1 = movinglist + block1
            print(block1)
        if block_to == 2:
            block2 = movinglist + block2
            print(block2)
        if block_to == 3:
            block3 = movinglist + block3
            print(block3)
        if block_to == 4:
            block4 = movinglist + block4
            print(block4)
        if block_to == 5:
            block5 = movinglist + block5
            print(block5)
        if block_to == 6:
            block6 = movinglist + block6
            print(block6)
        if block_to == 7:
            block7 = movinglist + block7
            print(block7)
        if block_to == 8:
            block8 = movinglist + block8
            print(block8)
        if block_to == 9:
            block9 = movinglist + block9
            print(block9)
if block_from == 3:
        block_from = block3  
        print(block_from)
        movinglist = (block3[:(how_many)])
        print(movinglist)
        block3 = block3[how_many:]
        print(block1)
        if block_to == 1:
            block1 = movinglist + block1
            print(block1)
        if block_to == 2:
            block2 = movinglist + block2
            print(block2)
        if block_to == 3:
            block3 = movinglist + block3
            print(block3)
        if block_to == 4:
            block4 = movinglist + block4
            print(block4)
        if block_to == 5:
            block5 = movinglist + block5
            print(block5)
        if block_to == 6:
            block6 = movinglist + block6
            print(block6)
        if block_to == 7:
            block7 = movinglist + block7
            print(block7)
        if block_to == 8:
            block8 = movinglist + block8
            print(block8)
        if block_to == 9:
            block9 = movinglist + block9
            print(block9)
if block_from == 4:
        block_from = block4  
        print(block_from)
        movinglist = (block4[:(how_many)])
        print(movinglist)
        block4 = block4[how_many:]
        print(block1)
        if block_to == 1:
            block1 = movinglist + block1
            print(block1)
        if block_to == 2:
            block2 = movinglist + block2
            print(block2)
        if block_to == 3:
            block3 = movinglist + block3
            print(block3)
        if block_to == 4:
            block4 = movinglist + block4
            print(block4)
        if block_to == 5:
            block5 = movinglist + block5
            print(block5)
        if block_to == 6:
            block6 = movinglist + block6
            print(block6)
        if block_to == 7:
            block7 = movinglist + block7
            print(block7)
        if block_to == 8:
            block8 = movinglist + block8
            print(block8)
        if block_to == 9:
            block9 = movinglist + block9
            print(block9)
if block_from == 5:
        block_from = block5  
        print(block_from)
        movinglist = (block5[:(how_many)])
        print(movinglist)
        block5 = block5[how_many:]
        print(block1)
        if block_to == 1:
            block1 = movinglist + block1
            print(block1)
        if block_to == 2:
            block2 = movinglist + block2
            print(block2)
        if block_to == 3:
            block3 = movinglist + block3
            print(block3)
        if block_to == 4:
            block4 = movinglist + block4
            print(block4)
        if block_to == 5:
            block5 = movinglist + block5
            print(block5)
        if block_to == 6:
            block6 = movinglist + block6
            print(block6)
        if block_to == 7:
            block7 = movinglist + block7
            print(block7)
        if block_to == 8:
            block8 = movinglist + block8
            print(block8)
        if block_to == 9:
            block9 = movinglist + block9
            print(block9)
if block_from == 6:
        block_from = block6  
        print(block_from)
        movinglist = (block6[:(how_many)])
        print(movinglist)
        block6 = block6[how_many:]
        print(block1)
        if block_to == 1:
            block1 = movinglist + block1
            print(block1)
        if block_to == 2:
            block2 = movinglist + block2
            print(block2)
        if block_to == 3:
            block3 = movinglist + block3
            print(block3)
        if block_to == 4:
            block4 = movinglist + block4
            print(block4)
        if block_to == 5:
            block5 = movinglist + block5
            print(block5)
        if block_to == 6:
            block6 = movinglist + block6
            print(block6)
        if block_to == 7:
            block7 = movinglist + block7
            print(block7)
        if block_to == 8:
            block8 = movinglist + block8
            print(block8)
        if block_to == 9:
            block9 = movinglist + block9
            print(block9)
if block_from == 7:
        block_from = block7  
        print(block_from)
        movinglist = (block7[:(how_many)])
        print(movinglist)
        block7 = block7[how_many:]
        print(block1)
        if block_to == 1:
            block1 = movinglist + block1
            print(block1)
        if block_to == 2:
            block2 = movinglist + block2
            print(block2)
        if block_to == 3:
            block3 = movinglist + block3
            print(block3)
        if block_to == 4:
            block4 = movinglist + block4
            print(block4)
        if block_to == 5:
            block5 = movinglist + block5
            print(block5)
        if block_to == 6:
            block6 = movinglist + block6
            print(block6)
        if block_to == 7:
            block7 = movinglist + block7
            print(block7)
        if block_to == 8:
            block8 = movinglist + block8
            print(block8)
        if block_to == 9:
            block9 = movinglist + block9
            print(block9)
if block_from == 8:
        block_from = block8  
        print(block_from)
        movinglist = (block8[:(how_many)])
        print(movinglist)
        block8 = block8[how_many:]
        print(block1)
        if block_to == 1:
            block1 = movinglist + block1
            print(block1)
        if block_to == 2:
            block2 = movinglist + block2
            print(block2)
        if block_to == 3:
            block3 = movinglist + block3
            print(block3)
        if block_to == 4:
            block4 = movinglist + block4
            print(block4)
        if block_to == 5:
            block5 = movinglist + block5
            print(block5)
        if block_to == 6:
            block6 = movinglist + block6
            print(block6)
        if block_to == 7:
            block7 = movinglist + block7
            print(block7)
        if block_to == 8:
            block8 = movinglist + block8
            print(block8)
        if block_to == 9:
            block9 = movinglist + block9
            print(block9)
if block_from == 9:
        block_from = block9  
        print(block_from)
        movinglist = (block9[:(how_many)])
        print(movinglist)
        block9 = block9[how_many:]
        print(block1)
        if block_to == 1:
            block1 = movinglist + block1
            print(block1)
        if block_to == 2:
            block2 = movinglist + block2
            print(block2)
        if block_to == 3:
            block3 = movinglist + block3
            print(block3)
        if block_to == 4:
            block4 = movinglist + block4
            print(block4)
        if block_to == 5:
            block5 = movinglist + block5
            print(block5)
        if block_to == 6:
            block6 = movinglist + block6
            print(block6)
        if block_to == 7:
            block7 = movinglist + block7
            print(block7)
        if block_to == 8:
            block8 = movinglist + block8
            print(block8)
        if block_to == 9:
            block9 = movinglist + block9
            print(block9)
# Out:
# block_from is 1
# ['N', 'T', 'B', 'S', 'Q', 'H', 'G', 'R']
# ['N', 'T', 'B']
# ['B', 'T', 'N']
# ['S', 'Q', 'H', 'G', 'R']
# ['B', 'T', 'N', 'J', 'Z', 'P', 'D', 'F', 'S', 'H']
